# %% [markdown]
# # Example Sheet 1 — Computational exercises
#
# ## Question 4: Numerical exploration of the positive-feedback model
#
# Return to the positive-feedback model from Question 2,
# $$
# \dot p=\beta p^2-\gamma p,\qquad p(0)=p_0.
# $$
# In this question, use
# $$
# \beta=1,\qquad \gamma=1.
# $$
#
# **(a)** Implement the right-hand side of the ODE in Python and use
# `scipy.integrate.solve_ivp` to simulate the system for
# $$
# p_0\in\{0.2,\,0.8,\,1.0,\,1.2\}.
# $$
# Plot all trajectories on the same axes. For a trajectory that grows rapidly,
# stop the integration when $p=10$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp # TODO: control click on solve_ivp and read the documentation
from scipy.optimize import root

beta = 1.0
gamma = 1.0

def rhs(t, y):
    # TODO: return dp/dt as a one-element list/array
    pass

def large_p(t, y):
    # TODO: event function that is zero when p >= 10; check the documentation if unclear
    pass

# Configure the event so integration terminates when p increases through 10
large_p.terminal = True
large_p.direction = -1

p0_values = [0.2, 0.8, 1.0, 1.2]

plt.figure(figsize=(7, 4.5))
for p0 in p0_values:
    # TODO:
    # 1. simulate each initial condition with solve_ivp to obtain p(t)
    # 2. plot p(t) for each trajectory using plt.plot(...)
    # 3. label the axes and add a legend
    pass

# %% [markdown]
# **(b)** On the same figure, plot the analytical solution from Question 2
# for each initial condition and compare it with the numerical solution.

# %%
def p_analytical(t, p0):
    # TODO: analytical solution from Question 2
    pass

# TODO: plot numerical and analytical solutions together

# %% [markdown]
# **(c)** Use a numerical root finder, such as `scipy.optimize.root`,
# with several initial guesses to find all non-negative equilibria.
# Compare your numerical results with the equilibria found analytically
# in Question 2.

# %%
guesses = [0.05, 0.25, 0.75, 1.25, 2.0]
equilibria = []

# TODO:
# loop over the guesses, call scipy.optimize.root,
# retain non-negative roots, and remove duplicates

equilibria

# %% [markdown]
# **(d)** Starting slightly above and below each equilibrium, simulate the
# ODE and use the resulting trajectories to classify each equilibrium as
# stable or unstable.

# %%
eps = 1e-2

# TODO:
# simulate from p* - eps and p* + eps around each equilibrium
# plot the trajectories and classify each equilibrium

# %% [markdown]
# **(e)** For $p_0=1.2$, estimate from the numerical simulation the time at
# which the solution becomes unbounded. Compare this with the time
# predicted by the analytical solution from Question 2.

# %%
p0 = 1.2

# TODO:
# estimate the blow-up time numerically.
# One approach is to stop at successively larger thresholds
# (e.g. p = 10, 100, 1000) and inspect the event times.

numerical_estimate = None
numerical_estimate

# %% [markdown]
# **Your comparison / interpretation:**
# _Write a short response here._
